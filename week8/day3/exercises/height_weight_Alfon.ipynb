# %% [markdown]
# ### Se pide, usando regresión lineal:
#
# Dibujar con una línea la relación que hay entre la altura y la edad de los alumnos de la clase:
#
# - ¿Es una buena técnica para este tipo de problemas? ¿Por qué?
# - ¿Qué error se comete? Calcula los errores que está cometiendo tu modelo uno a uno (lo tienes que calcular tú con python). Aparte, usa el MSE y el RMSE. ¿Alguno es mejor para este problema?
# - Representa la matriz de correlación, ¿los datos están correlacionados?
# - ¿Qué ocurre si la altura se multiplica por dos? ¿Y si se multiplica solo la edad?

# %% [markdown]
# ## Refresca teoria

# %%
# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=101)
#creating LinearRegression Object
lm = LinearRegression(n_jobs=-1)  # -1 to use all processors
#Training the Data Model
lm.fit(X_train, y_train)
# Using our model to predict test values
predictions = lm.predict(X_test)


# Error Calculations
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

# Score of our model in %
lm.score(X_train, y_train) * 100 # Entrenamiento

# %%
# Importando librerias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
lista_edad_altura = [[29, 1.66], [22, 1.83], [31, 1.80], [27, 1.75], [22, 1.82], [35, 1.79], [34, 1.90], [26, 1.78], [26, 1.64], [23, 1.74], [24, 1.85], [28, 1.75], [23, 1.83], [32,1.74], [34, 1.57], [27, 1.58], [38, 1.70], [22, 1.79]]

# %%
# Dos formas distintas de meter posiciones de sublistas en una nueva lista
edades = [item[0] for item in lista_edad_altura]
alturas = list(list(zip(*lista_edad_altura))[1])

# %%
# Meterlo en dataframe para que sea comodo
df_e_a = pd.DataFrame({'edades': edades, 'alturas': alturas})
df_e_a
# Out:
#     edades  alturas
# 0       29     1.66
# 1       22     1.83
# 2       31     1.80
# 3       27     1.75
# 4       22     1.82
# 5       35     1.79
# 6       34     1.90
# 7       26     1.78
# 8       26     1.64
# 9       23     1.74
# 10      24     1.85
# 11      28     1.75
# 12      23     1.83
# 13      32     1.74
# 14      34     1.57
# 15      27     1.58
# 16      38     1.70
# 17      22     1.79

# %%
# Defining variables
x = np.array(alturas).reshape(-1, 1)
y = np.array(edades)

# Creating an instance of the model
lin_reg = LinearRegression(n_jobs=-1)
# Splitting the data into 80-20, using age as target and height as independent variable
alt_train, alt_test, ed_train, ed_test = train_test_split(x, y, test_size=0.8, random_state=101)
#Training the Data Model
lin_reg.fit(alt_train, ed_train)
# Using our model to predict test values
predictions = lin_reg.predict(alt_test)
# Score of our model in %
score_train = lin_reg.score(alt_train, ed_train) * 100
score_test = lin_reg.score(alt_test, ed_test) * 100
print('Score of our training model:', score_train, '%')
print('Score of our test model:', score_test, '%')
# Out:
# Score of our training model: 82.8325823328394 %
# Score of our test model: -63.18871644124595 %

# %%
# Visualizacion
plt.scatter(alt_test, ed_test, edgecolors='black')
plt.plot(alt_test, predictions, color='red')
plt.xlabel('Height (m)')
plt.ylabel('Age (years)')
plt.title('Linear Regression of Age-Height relation')
plt.legend(['Predicted', 'Real'])

# %%
# Correlations
sns.heatmap(df_e_a.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## No hay correlacion, se acerca a zero

# %%
# Error Calculations
print('MAE:', mean_absolute_error(ed_test, predictions))
print('MSE:', mean_squared_error(ed_test, predictions))
print('RMSE:', np.sqrt(mean_squared_error(ed_test, predictions)))
# Out:
# MAE: 5.641439098396187
# MSE: 42.60313423892795
# RMSE: 6.527107647260611

# %% [markdown]
# ## Te da igual que error usar porque al no haber relacion entre las variables la prediccion va a ser una basura pase lo que pase.

# %% [markdown]
# ## No es una buena tecnica porque no hay relacion lineal entre las variables

# %%
# Multiplicando por 2 las variables

# Primero edad

# Defining variables
x = np.array(alturas).reshape(-1, 1)
y = 2 * np.array(edades)

# Creating an instance of the model
lin_reg = LinearRegression(n_jobs=-1)
# Splitting the data into 80-20, using age as target and height as independent variable
alt_train, alt_test, ed_train, ed_test = train_test_split(x, y, test_size=0.8, random_state=101)
#Training the Data Model
lin_reg.fit(alt_train, ed_train)
# Using our model to predict test values
predictions = lin_reg.predict(alt_test)
# Score of our model in %
score_train = lin_reg.score(alt_train, ed_train) * 100
score_test = lin_reg.score(alt_test, ed_test) * 100

# Visualizacion
plt.scatter(alt_test, ed_test, edgecolors='black')
plt.plot(alt_test, predictions, color='red')
plt.xlabel('Height (m)')
plt.ylabel('Age x2 (years)')
plt.title('Linear Regression of AgeX2-Height relation')
plt.legend(['Predicted', 'Real'])

# %%
# Ahora alturas

# Defining variables
x = 2 * np.array(alturas).reshape(-1, 1)
y = np.array(edades)

# Creating an instance of the model
lin_reg = LinearRegression(n_jobs=-1)
# Splitting the data into 80-20, using age as target and height as independent variable
alt_train, alt_test, ed_train, ed_test = train_test_split(x, y, test_size=0.8, random_state=101)
#Training the Data Model
lin_reg.fit(alt_train, ed_train)
# Using our model to predict test values
predictions = lin_reg.predict(alt_test)
# Score of our model in %
score_train = lin_reg.score(alt_train, ed_train) * 100
score_test = lin_reg.score(alt_test, ed_test) * 100

# Visualizacion
plt.scatter(alt_test, ed_test, edgecolors='black')
plt.plot(alt_test, predictions, color='red')
plt.xlabel('Height x2 (m)')
plt.ylabel('Age (years)')
plt.title('Linear Regression of Age-HeightX2 relation')
plt.legend(['Predicted', 'Real'])

# %% [markdown]
# # Sigue siendo una basura de prediccion!!
