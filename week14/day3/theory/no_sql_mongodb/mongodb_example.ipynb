# %%
# !pip install pymongo
# !pip install pymongo[srv]
# !pip install dnspython

# %%
import pymongo
from pymongo import MongoClient
client = MongoClient('mongodb+srv://root:test@cluster0.vpkaj.mongodb.net/test')
client
# Out:
# MongoClient(host=['cluster0-shard-00-01.vpkaj.mongodb.net:27017', 'cluster0-shard-00-00.vpkaj.mongodb.net:27017', 'cluster0-shard-00-02.vpkaj.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-9gyqiq-shard-0', ssl=True)

# %%
#{Country:"Andorra "}

# %%
db = client['data']
db.list_collection_names()
# Out:
# ['data_collection', 'nfl']

# %%
collection = db['data_collection']
collection.index_information()
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]}}

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('5f8d4feac8e009200c340c62'),
#  'Country': 'Austria ',
#  'Region': 'WESTERN EUROPE                     ',
#  'Population': '8192880',
#  'Area (sq': {' mi': {')': '83870'}},
#  'Pop': {' Density (per sq': {' mi': {')': '97,7'}}},
#  'Coastline (coast/area ratio)': '0,00',
#  'Net migration': '2',
#  'Infant mortality (per 1000 births)': '4,66',
#  'GDP ($ per capita)': '30000',
#  'Literacy (%)': '98,0',
#  'Phones (per 1000)': '452,2',
#  'Arable (%)': '16,91',
#  'Crops (%)': '0,86',
#  'Other (%)': '82,23',
#  'Climate': '3',
#  'Birthrate': '8,74',
#  'Deathrate': '9,76',
#  'Agriculture': '0,018',
#  'Industry': '0,304',
#  'Service': '0,678'}

# %%
import pandas as pd

df = pd.DataFrame(data=[collection.find_one()])
df
# Out:
#                         _id   Country                               Region  \
# 0  5f8d4feac8e009200c340c62  Austria   WESTERN EUROPE
#
#   Population                 Area (sq  \
# 0    8192880  {' mi': {')': '83870'}}
#
#                                             Pop Coastline (coast/area ratio)  \
# 0  {' Density (per sq': {' mi': {')': '97,7'}}}                         0,00
#
#   Net migration Infant mortality (per 1000 births) GDP ($ per capita)  ...  \
# 0             2                               4,66              30000  ...
#
#   Phones (per 1000) Arable (%) Crops (%) Other (%) Climate Birthrate  \
# 0             452,2      16,91      0,86     82,23       3      8,74
#
#   Deathrate Agriculture Industry Service
# 0      9,76       0,018    0,304   0,678
#
# [1 rows x 21 columns]

# %%
fetch_albania = collection.find({}, {'Country': "Albania"})
fetch_albania

# %%
fetch_albania = collection.find({}, {'Country': "Albania"})
for y in fetch_albania:
    object_id = y["_id"]
    print(y)
# Out:
# nia'}
# {'_id': ObjectId('5f8ec154c8e009200c341c11'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c12'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c13'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c14'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c15'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c16'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c17'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c18'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c19'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c1a'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c1b'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c1c'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c1d'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c1e'), 'Country': 'Albania'}
# ...

# %%
for i in collection.find({},{'Country': 'Austria ', 'Population': '8192880', 'Other (%)': '82,23',
 'Climate': '3',
 'Birthrate': '8,74',
 'Deathrate': '9,76',
 'Agriculture': '0,018',
 'Industry': '0,304',
 'Service': '0,678'}).limit(1):
    print(i)
# Out:
# {'_id': ObjectId('5f8d4feac8e009200c340c62'), 'Country': 'Austria ', 'Population': '8192880', 'Other (%)': '82,23', 'Climate': '3', 'Birthrate': '8,74', 'Deathrate': '9,76', 'Agriculture': '0,018', 'Industry': '0,304', 'Service': '0,678'}

# %%
fetch_albania = collection.find({}, {'Country': "Albania"})
for y in fetch_albania:
    object_id = y["_id"]
    print(object_id)
    for x in collection.find():
        if x["_id"] == object_id:
            print(x)
            break
# Out:
# ', 'GDP ($ per capita)': '800', 'Literacy (%)': '42,4', 'Phones (per 1000)': '7,4', 'Arable (%)': '10,67', 'Crops (%)': '8,82', 'Other (%)': '80,51', 'Climate': '2', 'Birthrate': '37,22', 'Deathrate': '16,53', 'Agriculture': '0,62', 'Industry': '0,12', 'Service': '0,26'}
# 5f8d4feac8e009200c340c85
# {'_id': ObjectId('5f8d4feac8e009200c340c85'), 'Country': 'Cook Islands ', 'Region': 'OCEANIA                            ', 'Population': '21388', 'Area (sq': {' mi': {')': '240'}}, 'Pop': {' Density (per sq': {' mi': {')': '89,1'}}}, 'Coastline (coast/area ratio)': '50,00', 'Net migration': '', 'Infant mortality (per 1000 births)': '', 'GDP ($ per capita)': '5000', 'Literacy (%)': '95,0', 'Phones (per 1000)': '289,9', 'Arable (%)': '17,39', 'Crops (%)': '13,04', 'Other (%)': '69,57', 'Climate': '2', 'Birthrate': '21', 'Deathrate': '', 'Agriculture': '0,151', 'Industry': '0,096', 'Service': '0,753'}
# 5f8d4feac8e009200c340ccc
# ...

# %%
fetch_albania = collection.find({},{'Country': "Albania"})
for x in fetch_albania:
    print(x)
    break
# Out:
# {'_id': ObjectId('5f8d4feac8e009200c340c62'), 'Country': 'Albania'}

# %%
fetch_albania = collection.find({}, {'Country': "Albania"})
for x in fetch_albania:
    print(x)
# Out:
# nia'}
# {'_id': ObjectId('5f8ec154c8e009200c341c11'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c12'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c13'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c14'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c15'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c16'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c17'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c18'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c19'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c1a'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c1b'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c1c'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c1d'), 'Country': 'Albania'}
# {'_id': ObjectId('5f8ec154c8e009200c341c1e'), 'Country': 'Albania'}
# ...

# %%
fetch_albania = collection.find({}, {'_id': "5f8d4feac8e009200c340ca4"})
for x in fetch_albania:
    print(x)
# Out:
# ac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# {'_id': '5f8d4feac8e009200c340ca4'}
# ...

# %%
# Inserting one record
record = {'_id': "ObjectId('5f8d4feac8e009200c340c62')",
        'Country': 'Austria2 ',
        'Region': 'WESTERN EUROPE                     ',
        'Population': '8192880',
        'Area (sq': {' mi': {')': '83870'}},
        'Pop': {' Density (per sq': {' mi': {')': '97,7'}}},
        'Coastline (coast/area ratio)': '0,00',
        'Net migration': '2',
        'Infant mortality (per 1000 births)': '4,66',
        'GDP ($ per capita)': '30000',
        'Literacy (%)': '98,0',
        'Phones (per 1000)': '452,2',
        'Arable (%)': '16,91',
        'Crops (%)': '0,86',
        'Other (%)': '82,23',
        'Climate': '3',
        'Birthrate': '8,74',
        'Deathrate': '9,76',
        'Agriculture': '0,018',
        'Industry': '0,304',
        'Service': '0,678'
 }
collection.insert_one(record)
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# <ipython-input-34-0dafe65d6ba8> in <module>
#      22         'Service': '0,678'
#      23  }
# ---> 24 collection.insert_one(record)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     696         write_concern = self._write_concern_for(session)
#     697         return InsertOneResult(
# --> 698             self._insert(document,
#     699                          write_concern=write_concern,
#     700                          bypass_doc_val=bypass_document_validation,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
# ...

# %%
collection.insert_many(records)

# %%
# delete
collection.delete_one({"State": "Maharastra"})
